# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Vehicles case

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
x = [0.05, 0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85]
y = [308.46, 318.43, 327.51, 341.34, 357.38, 382.64, 401.75, 413.65, 424.65]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Añadir títulos y etiquetas
plt.title('Scatter Plot Cost VS Probability of resources failure')
plt.xlabel('Probability')
plt.ylabel('Cost')

# Calcular la línea de mejor ajuste
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Dibujar la línea de mejor ajuste
plt.plot(x, y_fit, color='blue')

# Mostrar el gráfico
plt.savefig('Cost_Prob_Correlation.pdf', format='pdf')
plt.show()

# %%
data = pd.DataFrame({'x': x, 'y': y})
correlation = data['x'].corr(data['y'])
print(correlation)
# Out:
# 0.9921766428814364

# %%
# Datos de ejemplo
x = [0.05, 0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85]
y = [16.15, 16.18, 16.82, 16.96, 17.18, 17.54, 17.81, 18.32, 18.68]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Añadir títulos y etiquetas
plt.title('Scatter Plot Timespan VS Probability of resources failure')
plt.xlabel('Probability')
plt.ylabel('Timespan')

# Calcular la línea de mejor ajuste
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Dibujar la línea de mejor ajuste
plt.plot(x, y_fit, color='blue')

plt.savefig('Time_Prob_Correlation.pdf', format='pdf')
# Mostrar el gráfico
plt.show()

# %%
data = pd.DataFrame({'x': x, 'y': y})
correlation = data['x'].corr(data['y'])
print(correlation)
# Out:
# 0.9903367891490112

# %%
# Datos de ejemplo
x = [0.1, 0.17, 0.25, 0.37, 0.5, 0.67, 0.75, 0.87, 1]
y = [308.46, 314.57, 318.62, 320.68, 330.54, 336.42, 338.43, 341.78, 345.37]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Añadir títulos y etiquetas
plt.title('Scatter Plot Cost VS Variance')
plt.xlabel('Variance')
plt.ylabel('Cost')

# Calcular la línea de mejor ajuste
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Dibujar la línea de mejor ajuste
plt.plot(x, y_fit, color='blue')

plt.savefig('Cost_Var_Correlation.pdf', format='pdf')
# Mostrar el gráfico
plt.show()

# %%
data = pd.DataFrame({'x': x, 'y': y})
correlation = data['x'].corr(data['y'])
print(correlation)
# Out:
# 0.9881909395593579

# %%
# Datos de ejemplo
x = [0.1, 0.17, 0.25, 0.37, 0.5, 0.67, 0.75, 0.87, 1]
y = [16.15, 16.28, 16.63, 16.72, 16.76, 16.98, 17.34, 17.48, 17.68]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Añadir títulos y etiquetas
plt.title('Scatter Plot Timespan VS Variance')
plt.xlabel('Variance')
plt.ylabel('Timespan')

# Calcular la línea de mejor ajuste
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Dibujar la línea de mejor ajuste
plt.plot(x, y_fit, color='blue')

plt.savefig('Time_Var_Correlation.pdf', format='pdf')
# Mostrar el gráfico
plt.show()

# %%
data = pd.DataFrame({'x': x, 'y': y})
correlation = data['x'].corr(data['y'])
print(correlation)
# Out:
# 0.9813869766786963

# %% [markdown]
# # Robomax case

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
x = [0.05, 0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85]
y = [15.2, 15.6, 16.2, 16.1, 15.7, 16.6, 17, 17.2, 16.8]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Añadir títulos y etiquetas
plt.title('Scatter Plot Disruption VS Probability of resources failure')
plt.xlabel('Probability')
plt.ylabel('Number of disruptions')

# Calcular la línea de mejor ajuste
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Dibujar la línea de mejor ajuste
plt.plot(x, y_fit, color='blue')

# Mostrar el gráfico
plt.savefig('Dis_Prob_Correlation_R.pdf', format='pdf')
plt.show()

# %%
data = pd.DataFrame({'x': x, 'y': y})
correlation = data['x'].corr(data['y'])
print(correlation)
# Out:
# 0.8878512585999438

# %%
# Datos de ejemplo
x = [0.05, 0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85]
y = [16.28, 16.34, 16.52, 17.15, 17.28, 17.84, 18.03, 18.42, 18.68]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Añadir títulos y etiquetas
plt.title('Scatter Plot Timespan VS Probability of resources failure')
plt.xlabel('Probability')
plt.ylabel('Timespan')

# Calcular la línea de mejor ajuste
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Dibujar la línea de mejor ajuste
plt.plot(x, y_fit, color='blue')

plt.savefig('Time_Prob_Correlation_R.pdf', format='pdf')
# Mostrar el gráfico
plt.show()

# %%
data = pd.DataFrame({'x': x, 'y': y})
correlation = data['x'].corr(data['y'])
print(correlation)
# Out:
# 0.990089830177502

# %%
# Datos de ejemplo
x = [0.1, 0.17, 0.25, 0.37, 0.5, 0.67, 0.75, 0.87, 1]
y = [15.4, 15.2, 15.8, 16.2, 16.5, 16.6, 17.2, 17, 16.8]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Añadir títulos y etiquetas
plt.title('Scatter Plot Disruption VS Varianza')
plt.xlabel('Variance')
plt.ylabel('Number of Disruptions')

# Calcular la línea de mejor ajuste
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Dibujar la línea de mejor ajuste
plt.plot(x, y_fit, color='blue')

plt.savefig('Dis_Var_Correlation_R.pdf', format='pdf')
# Mostrar el gráfico
plt.show()

# %%
data = pd.DataFrame({'x': x, 'y': y})
correlation = data['x'].corr(data['y'])
print(correlation)
# Out:
# 0.9117637475317449

# %%
# Datos de ejemplo
x = [0.1, 0.17, 0.25, 0.37, 0.5, 0.67, 0.75, 0.87, 1]
y = [16.08, 16.15, 16.43, 16.68, 16.86, 17.12, 17.44, 17.58, 17.74]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Añadir títulos y etiquetas
plt.title('Scatter Plot Timespan VS Variance')
plt.xlabel('Variance')
plt.ylabel('Timespan')

# Calcular la línea de mejor ajuste
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Dibujar la línea de mejor ajuste
plt.plot(x, y_fit, color='blue')

plt.savefig('Time_Var_Correlation_R.pdf', format='pdf')
# Mostrar el gráfico
plt.show()

# %%
data = pd.DataFrame({'x': x, 'y': y})
correlation = data['x'].corr(data['y'])
print(correlation)
# Out:
# 0.9943466802592233

# %%
# Datos de ejemplo
x = [15.2, 15.6, 16.2, 16.1, 15.7, 16.6, 17, 17.2, 16.8]
y = [16.28, 16.34, 16.52, 17.15, 17.28, 17.84, 18.03, 18.42, 18.68]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Añadir títulos y etiquetas
plt.title('Scatter Plot Disruption VS Varianza')
plt.xlabel('Variance')
plt.ylabel('Number of Disruptions')

# Calcular la línea de mejor ajuste
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Dibujar la línea de mejor ajuste
plt.plot(x, y_fit, color='blue')

plt.savefig('Dis_Var_Correlation_R.pdf', format='pdf')
# Mostrar el gráfico
plt.show()

# %%
x = [308.46, 314.57, 318.62, 320.68, 330.54, 336.42, 338.43, 341.78, 345.37]
y = [16.28, 16.34, 16.52, 17.15, 17.28, 17.84, 18.03, 18.42, 18.68]

# %%
data = pd.DataFrame({'x': x, 'y': y})
correlation = data['x'].corr(data['y'])
print(correlation)
# Out:
# 0.9764331865864049
